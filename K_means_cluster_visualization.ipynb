# %%
import matplotlib.pyplot as plt

# The input string of values (x coordinate, y coordinate, cluster represented as a color in the plot)
data_str = """1.2,1.5,4
1.1,1.3,4
1.4,1.2,4
1.3,1.1,4
1.5,1.4,4
8.5,8.3,7
7.9,8.2,7
7.8,8.6,7
8.1,8,7
8.4,7.7,7
22.1,4.9,6
21.5,5.3,6
22,5,6
21.8,5.1,6
21.9,5.2,6
14.8,14.9,1
14.4,15.2,1
15.1,14.7,5
14.5,14.6,1
14.3,14.9,1
26.5,5.9,6
25.9,5.8,6
26.1,5.7,6
26.3,5.6,6
26,5.5,6
14.3,15.7,0
14.6,15.3,1
14.5,15.6,0
14.4,15.8,0
14.7,15.4,1
4.1,5.6,7
4,5.5,7
3.9,5.7,7
4.3,5.4,7
4.2,5.6,7
24.9,5.1,6
25.1,5.3,6
24.8,5.2,6
25,5.4,6
25.2,5,6
4,4,3
4.2,3.9,3
3.9,4.2,3
3.8,4.1,3
4.1,4.3,3
14.9,14.3,5
15,14.5,5
14.8,14.7,5
14.6,14.4,5
14.5,14.6,1
8.3,7.9,7
8.1,8.5,7
8,7.8,7
8.2,8.6,7
7.7,8.4,7
25.5,5.5,6
25.2,5.6,6
25.3,5.8,6
25.4,5.7,6
25.1,5.9,6
1.6,1.8,4
1.3,1.7,4
1.5,1.6,4
1.2,1.9,4
1.4,1.7,4
5.5,4,2
5.2,4.1,2
5.4,4.3,2
5.3,4.2,2
5.1,4,2
14.6,15.2,1
14.7,15.3,1
15.1,15.4,1
14.9,15,1
14.8,15.5,0
21.7,4.9,6
22.1,5.2,6
21.9,5,6
21.8,4.8,6
21.5,5.1,6
14.3,15.5,0
14.6,15.7,0
14.5,15.6,0
14.7,15.3,1
14.4,15.8,0
4.1,5.5,7
4.2,5.4,7
4,5.6,7
3.9,5.7,7
4.3,5.3,7
21.5,5.1,6
21.9,4.8,6
22.1,5.3,6
21.7,4.9,6
21.8,5,6
14.6,15.4,1
14.5,15.6,0
14.4,15.5,0
14.3,15.7,0
14.7,15.3,1"""

# Parse the input string and extract coordinates and colors
coordinates = []
colors = []
for line in data_str.split('\n'):
    x, y, color = map(float, line.split(','))
    coordinates.append((x, y))
    colors.append(color)

# Create a colormap with different colors for each number
unique_colors = list(set(colors))
color_map = plt.cm.get_cmap('tab20', len(unique_colors))

# Plot the points with different colors
for i, (x, y) in enumerate(coordinates):
    color = color_map(unique_colors.index(colors[i]))
    plt.scatter(x, y, c=[color], s=50)

# Add labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Clusters')

# Show the plot
plt.show()
# Out:
# <ipython-input-10-76f5077ae6ee>:115: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   color_map = plt.cm.get_cmap('tab20', len(unique_colors))
